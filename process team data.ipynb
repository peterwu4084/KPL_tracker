# %%
import numpy as np
import pandas as pd

# %%
team_assault = pd.read_csv('team_assault.csv', index_col=0)
team_resource = pd.read_csv('team_resource.csv', index_col=0)

# %%
team = pd.merge(team_assault, team_resource)
team.head(5)
# Out:
#    名次     战队  KDA  场均击杀  场均助攻  场均死亡   场均经济  分钟经济   胜场场均时长   负场场均时长    一血率  \
# 0   1    DYG  4.5  12.8  30.1   9.5  60518  3078  1110.53  1346.71  54.2%
# 1   2  LGD大鹅  4.0  11.9  26.9   9.8  62444  3159  1193.67  1163.00  50.0%
# 2   3  AG超玩会  3.9  12.3  30.4  11.0  55620  3065  1108.56  1043.00  47.8%
# 3   4     GK  3.7  13.0  31.5  12.1  59700  2973  1228.15  1166.75  38.1%
# 4   5     WE  3.6  14.0  30.3  12.3  59881  3018  1096.14  1337.11  52.2%
#
#    场均主宰  场均暴君  主宰控制率  暴君控制率  场均野怪击杀量   总推塔数  总被推塔数  场均推塔数
# 0   0.8   1.0  56.2%  56.8%    106.0  147.0  104.0    6.1
# 1   1.1   1.6  63.6%  77.5%    124.0  144.0   76.0    7.2
# 2   0.5   0.7  42.3%  37.2%     90.0  138.0   99.0    6.0
# 3   0.7   0.9  43.8%  46.3%     88.0  114.0  116.0    5.4
# 4   0.8   1.3  61.3%  67.4%    108.0  144.0  100.0    6.3

# %%
team.describe()
# Out:
#               名次        KDA      场均击杀       场均助攻       场均死亡         场均经济  \
# count  16.000000  16.000000  16.00000  16.000000  16.000000     16.00000
# mean    8.500000   3.312500  11.43125  26.231250  11.437500  58062.31250
# std     4.760952   0.553624   1.44440   3.694811   0.941541   2671.15732
# min     1.000000   2.500000   9.20000  20.200000   9.500000  53090.00000
# 25%     4.750000   2.875000  10.57500  23.050000  10.925000  56240.00000
# 50%     8.500000   3.300000  11.55000  25.450000  11.500000  58035.00000
# 75%    12.250000   3.625000  12.57500  30.150000  12.225000  60040.25000
# max    16.000000   4.500000  14.00000  31.500000  12.500000  62444.00000
#
#               分钟经济       胜场场均时长       负场场均时长       场均主宰       场均暴君  \
# count    16.000000    16.000000    16.000000  16.000000  16.000000
# mean   2960.812500  1177.717500  1176.553125   0.700000   0.981250
# std      89.626052    79.407163    89.112563   0.175119   0.280995
# min    2798.000000  1091.400000   979.500000   0.400000   0.600000
# 25%    2908.750000  1120.385000  1156.425000   0.600000   0.775000
# 50%    2952.500000  1157.475000  1169.375000   0.700000   1.000000
# 75%    2996.250000  1206.595000  1201.705000   0.800000   1.100000
# max    3159.000000  1388.080000  1346.710000   1.100000   1.600000
#
#           场均野怪击杀量        总推塔数       总被推塔数      场均推塔数
# count   16.000000   16.000000   16.000000  16.000000
# mean    96.250000  121.875000  121.875000   5.356250
# std     10.063134   23.655514   30.172559   0.860983
# min     84.000000   89.000000   76.000000   3.900000
# 25%     89.000000  101.500000   99.750000   4.700000
# 50%     94.000000  117.500000  116.500000   5.300000
# 75%    101.250000  144.000000  144.250000   6.000000
# max    124.000000  165.000000  191.000000   7.200000

# %%
team.dtypes
# Out:
# 名次           int64
# 战队          object
# KDA        float64
# 场均击杀       float64
# 场均助攻       float64
# 场均死亡       float64
# 场均经济         int64
# 分钟经济         int64
# 胜场场均时长     float64
# 负场场均时长     float64
# 一血率         object
# 场均主宰       float64
# 场均暴君       float64
# 主宰控制率       object
# 暴君控制率       object
# 场均野怪击杀量    float64
# 总推塔数       float64
# 总被推塔数      float64
# 场均推塔数      float64
# dtype: object

# %%
team.drop(columns=['名次', '场均经济', '场均主宰', '场均暴君', '场均主宰', 
                   '场均暴君', '场均野怪击杀量', '总推塔数', '总被推塔数'], inplace=True)

# %%
team['一血率'] = team['一血率'].apply(lambda s: float(s[:-1]))
team['主宰控制率'] = team['主宰控制率'].apply(lambda s: float(s[:-1]))
team['暴君控制率'] = team['暴君控制率'].apply(lambda s: float(s[:-1]))

# %%
team['控龙'] = team['主宰控制率'] + team['暴君控制率']
team['终结'] = team['负场场均时长']/team['胜场场均时长']
team['KDA'] = (team['场均击杀'] + team['场均助攻']) / team['场均死亡']

# %%
team.drop(columns=['胜场场均时长', '负场场均时长', '主宰控制率', '暴君控制率',
                  '场均击杀', '场均助攻', '场均死亡',], inplace=True)

# %%
team.rename(columns={'分钟经济': '发育', '一血率': '一血', '场均推塔数': '推塔'}, inplace=True)

# %%
team
# Out:
#           战队       KDA    发育    一血   推塔     控龙        终结
# 0        DYG  4.515789  3078  54.2  6.1  113.0  1.212673
# 1      LGD大鹅  3.959184  3159  50.0  7.2  141.1  0.974306
# 2      AG超玩会  3.881818  3065  47.8  6.0   79.5  0.940860
# 3         GK  3.677686  2973  38.1  5.4   90.1  0.950006
# 4         WE  3.601626  3018  52.2  6.3  128.7  1.219835
# 5      RNG.M  3.516129  2956  60.0  5.8   86.5  1.018138
# 6    QGhappy  3.432692  2899  56.7  5.5  102.6  0.839541
# 7   eStarPro  3.438017  2989  58.8  6.0  130.2  0.888119
# 8        YTG  3.247788  2976  42.1  5.0  119.3  0.862031
# 9         TS  3.168224  2912  46.2  5.2   92.3  0.944268
# 10    TTG.XQ  3.065574  2942  59.1  5.2   74.5  0.988424
# 11        VG  2.877193  2949  46.2  4.7   98.7  1.024297
# 12     EDG.M  2.824561  2920  60.0  4.5   86.0  1.081428
# 13       TES  2.808000  2852  40.9  4.7   81.0  1.063071
# 14       RW侠  2.534483  2887  45.8  4.2   91.3  1.007223
# 15      Hero  2.520325  2798  41.7  3.9   95.4  1.043011

# %%
power_list = team.columns[1:]
team[power_list] = team[power_list].apply(lambda x: 5 * (x - np.min(x)) / (np.max(x) - np.min(x)) + 5)

# %%
team
# Out:
#           战队        KDA         发育         一血         推塔         控龙         终结
# 0        DYG  10.000000   8.878116   8.675799   8.333333   7.890390   9.905838
# 1      LGD大鹅   8.605323  10.000000   7.716895  10.000000  10.000000   6.771855
# 2      AG超玩会   8.411469   8.698061   7.214612   8.181818   5.375375   6.332117
# 3         GK   7.899979   7.423823   5.000000   7.272727   6.171171   6.452365
# 4         WE   7.709397   8.047091   8.219178   8.636364   9.069069  10.000000
# 5      RNG.M   7.495168   7.188366  10.000000   7.878788   5.900901   7.348146
# 6    QGhappy   7.286102   6.398892   9.246575   7.424242   7.109610   5.000000
# 7   eStarPro   7.299443   7.645429   9.726027   8.181818   9.181682   5.638690
# 8        YTG   6.822790   7.465374   5.913242   6.666667   8.363363   5.295693
# 9         TS   6.623429   6.578947   6.849315   6.969697   6.336336   6.376923
# 10    TTG.XQ   6.366220   6.994460   9.794521   6.969697   5.000000   6.957476
# 11        VG   5.894197   7.091413   6.849315   6.212121   6.816817   7.429127
# 12     EDG.M   5.762319   6.689751  10.000000   5.909091   5.863363   8.180257
# 13       TES   5.720822   5.747922   5.639269   6.212121   5.487988   7.938913
# 14       RW侠   5.035474   6.232687   6.757991   5.454545   6.261261   7.204640
# 15      Hero   5.000000   5.000000   5.821918   5.000000   6.569069   7.675165

# %%
team.to_csv('Data/team.csv')
